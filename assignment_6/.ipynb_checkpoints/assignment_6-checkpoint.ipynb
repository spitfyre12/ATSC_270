# %% [markdown]
# # ASSIGNMENT #6 - MODEL DATA #
# Due: 21 April 2024 @ 11:59p

# %% [markdown]
# Purpose:\
# The purpose of this assignment is to examine the netCDF data format using model data and plotting the output.
#
# Overview:\
# In this assignment you will read in ECMWF ERA-40 Reanalysis netCDF4 and plot the data on a map.
#
#
# | | UPDATE TO YOUR INFORMATION |
# | :- | :- |
# | Created By | Jared W. Marquis |
# | Creation Date | 21 January 2024 |
# | Course | ATSC 270 - Computer Concepts in Meteorology |

# %%
### UPDATE TO YOUR INFORMATION ###
#information allowing anyone with the code to print the author and contact information
__author__    = "Rebecca Jacoby"
__contact__   = "rebecca.jacoby@ndus.edu"

# %% [markdown]
# ### IMPORT REQUIRED LIBRARIES ###

# %%
import numpy as np
from datetime import datetime, timedelta
from netCDF4 import Dataset

import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### OPEN NETCDF FILE ###

# %%
data = Dataset('ECMWF_ERA-40_subset.nc','r')
    
#analyze the variables and plot (on a map) SLP, 10-m winds, and total precipitation
lat = data.variables['latitude'][:]
lon = data.variables['longitude'][:]
time = data.variables['time'][:] #hours since 1900-01-01 00:00:0.0


start_time = datetime(1900,1,1,0,0)
dts = np.empty(len(time), dtype=datetime)
for index, t in enumerate(time):
    dts[index] = start_time + timedelta(hours=int(t))
    
tp = data.variables['tp'][:]*1000
p10u = data.variables['p10u'][:]*1.94384
p10v = data.variables['p10v'][:]*1.94384
msl = data.variables['msl'][:]/100

# %%
plt.imshow(tp[7])
plt.colorbar()
plt.show()

# %%
proj = ccrs.PlateCarree()
fig = plt.figure(figsize=(10,10),dpi=100)
ax = fig.add_subplot(1,1,1,projection=proj)

clevs = np.arange(900,1100,4)


cs = ax.contour(lon,lat, msl[0], clevs, colors='black', transform=ccrs.PlateCarree())
ax.clabel(cs,inline=True,)#, fmt=lambda v: format(v, '.0f')[:3])

#plt.contour(lat, lon, tp[1] )
#plt.contour(p10v)   #60, transform=ccrs.PlateCarree())

#plot wind barbs
#lat[::5] #every 5th row, becasue lat and long are 3-dimensional
#lon[::5]

#Add features to the map
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

               #add a title with the date
#plt.title(f'{dt.strftime("%Y-%m-%d %HZ")}\nModel Data Map')

#set up the color bar (orientation=horizontal or vertical)
#cb = plt.colorbar(orientation='vertical')
#cb.set_label()

#save the map
#plt.savefig('Model Data Map.png')



#contour for pressure: 4mb step, with 1000mb baseline
#precip: 1-25 by 1
#contour for winds
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 9
#       5 clevs = np.arange(900,1100,4)
#       8 cs = ax.contour(lon,lat, msl[0], clevs, colors='black', transform=ccrs.PlateCarree())
# ----> 9 ax.clabel(cs,inline=True,)#, fmt=lambda v: format(v, '.0f')[:3])
#      11 #plt.contour(lat, lon, tp[1] )
#      12 #plt.contour(p10v)   #60, transform=ccrs.PlateCarree())
#      13
#    (...)
#      17
#      18 #Add features to the map
#      19 ax.add_feature(cfeature.COASTLINE)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/axes/_axes.py:6550, in Axes.clabel(self, CS, levels, **kwargs)
#    6532 def clabel(self, CS, levels=None, **kwargs):
#    6533     """
#    6534     Label a contour plot.
#    6535
#    (...)
#    6548         All other parameters are documented in `~.ContourLabeler.clabel`.
#    6549     """
# -> 6550     return CS.clabel(levels, **kwargs)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/cartopy/mpl/contour.py:93, in GeoContourSet.clabel(self, *args, **kwargs)
#      89                 paths.append(mpath.Path(verts, codes))
#      91 # Now that we have prepared the collection paths, call on
#      92 # through to the underlying implementation.
# ---> 93 return super().clabel(*args, **kwargs)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/contour.py:222, in ContourLabeler.clabel(self, levels, fontsize, inline, inline_spacing, fmt, colors, use_clabeltext, manual, rightside_up, zorder)
#     216     mpl._blocking_input.blocking_input_loop(
#     217         self.axes.figure, ["button_press_event", "key_press_event"],
#     218         timeout=-1, handler=functools.partial(
#     219             _contour_labeler_event_handler,
#     220             self, inline, inline_spacing))
#     221 else:
# --> 222     self.labels(inline, inline_spacing)
#     224 return cbook.silent_list('text.Text', self.labelTexts)
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/contour.py:622, in ContourLabeler.labels(self, inline, inline_spacing)
#     620 if self.print_label(screen_xys, label_width):
#     621     x, y, idx = self.locate_label(screen_xys, label_width)
# --> 622     rotation, path = self._split_path_and_get_label_rotation(
#     623         subpath, idx, (x, y),
#     624         label_width, inline_spacing)
#     625     add_label(x, y, rotation, lev, cvalue)  # Really add label.
#     626     if inline:  # If inline, add new contours
#
# File ~/miniconda3/envs/atsc270/lib/python3.11/site-packages/matplotlib/contour.py:373, in ContourLabeler._split_path_and_get_label_rotation(self, path, idx, screen_pos, lw, spacing)
#     369 # Find the connected component where the label will be inserted.  Note that a
#     370 # path always starts with a MOVETO, and we consider there's an implicit
#     371 # MOVETO (closing the last path) at the end.
#     372 movetos = (codes == Path.MOVETO).nonzero()[0]
# --> 373 start = movetos[movetos <= idx][-1]
#     374 try:
#     375     stop = movetos[movetos > idx][0]
#
# IndexError: index -1 is out of bounds for axis 0 with size 0
