# %% [markdown]
# # ASSIGNMENT #4 - SURFACE WEATHER DATA #
# Due: 31 March 2024 @ 11:59p

# %% [markdown]
# Purpose:\
# The purpose of this assignment is to continue to strengthen skills with reading in data by reading in surface observations from a text file.  The data is then plotted on a map to begin to familiarize with plotting weather data on maps.
#
# Overview:\
# In this assignment you will read in surface weather data, quality control that data, and plot that data .
#
#
# | | UPDATE TO YOUR INFORMATION |
# | :- | :- |
# | Created By | Jared W. Marquis |
# | Creation Date | 18 January 2024 |
# | Course | ATSC 270 - Computer Concepts in Meteorology |

# %%
### UPDATE TO YOUR INFORMATION ###
#information allowing anyone with the code to print the author and contact information
__author__    = "Rebecca Jacoby"
__contact__   = "rebecca.jacoby@ndus.edu"

# %% [markdown]
# ### IMPORT REQUIRED LIBRARIES ###

# %%
import numpy as np

import metpy.calc as mpcalc
from metpy.units import units
from metpy.plots import current_weather, sky_cover, StationPlot, simple_layout
from metpy.io import metar

import pandas as pd

import matplotlib.pyplot as plt

import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# ### OPEN OBSERVATIONS TEXT FILE ###
# Open the text file containing the surface observations using the metpy metar reader -> metar.parse_metar_file(filename).

# %%
filename = "metar_20240112_2100.txt"
data = metar.parse_metar_file(filename,year=2024,month=1)
#filename,year=2024,month=1

#convert air_temperature and dew_point_temperature from celsius to fahrenheight
data.air_temperature = (data.air_temperature*9/5) + 32
data.dew_point_temperature = (data.dew_point_temperature*9/5) + 32

#another way to do it: data['air_temperature'] = (data['air_temperature']*9/5) + 32

print(data)
# Out:
#            station_id  latitude   longitude  elevation           date_time  \
# station_id
# KGYH             KGYH     34.75  -82.380000      292.0 2024-01-12 20:47:00
# KMFV             KMFV     37.63  -75.770000       15.0 2024-01-12 20:55:00
# KPLD             KPLD     40.45  -84.983333      282.0 2024-01-12 20:55:00
# KIKT             KIKT     28.52  -88.280000       25.0 2024-01-12 20:50:00
# PAKU             PAKU     70.31 -149.580000        2.0 2024-01-12 20:45:00
# ...               ...       ...         ...        ...                 ...
# OIYY             OIYY     31.90   54.280000     1236.0 2024-01-12 21:50:00
# ORNI             ORNI     31.98   44.400000       53.0 2024-01-14 21:00:00
# NFTV             NFTV    -18.57 -173.970000       71.0 2024-01-12 21:00:00
# NFTL             NFTL    -19.78 -174.330000        3.0 2024-01-12 21:00:00
# NFTF             NFTF    -21.23 -175.150000       38.0 2024-01-12 21:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGYH                  60.0        12.0        NaN    4828.032         +RA
# KMFV                 100.0         6.0        NaN   16093.440         NaN
# KPLD                 130.0        10.0        NaN    8046.720         -SN
# KIKT                 240.0        22.0       32.0    4828.032          BR
# PAKU                 100.0        21.0        NaN    4828.032        BLSN
# ...                    ...         ...        ...         ...         ...
# OIYY                 120.0         4.0        NaN   10000.000         NaN
# ORNI                 240.0         7.0        NaN    6000.000         NaN
# NFTV                  90.0        15.0        NaN    9999.000       -SHRA
# NFTL                  90.0        22.0        NaN    9999.000         NaN
# NFTF                  90.0        16.0        NaN    9999.000         NaN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGYH        ...            44.6                  42.8     29.61
# KMFV        ...            48.2                  41.0     29.99
# KPLD        ...            33.8                  33.8     29.16
# KIKT        ...            73.4                  69.8     29.68
# PAKU        ...             5.0                   3.2     29.96
# ...         ...             ...                   ...       ...
# OIYY        ...            51.8                  26.6     29.88
# ORNI        ...            51.8                  42.8     30.03
# NFTV        ...            82.4                  75.2     29.88
# NFTL        ...            84.2                  73.4     29.91
# NFTF        ...            80.6                  73.4     29.94
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGYH                        65                 10                   0
# KMFV                         0                  0                   0
# KPLD                        71                  0                   0
# KIKT                        10                  0                   0
# PAKU                        38                 10                   0
# ...                        ...                ...                 ...
# OIYY                         0                  0                   0
# ORNI                         0                  0                   0
# NFTV                        80                  0                   0
# NFTL                         0                  0                   0
# NFTF                         0                  0                   0
#
#                   remarks  air_pressure_at_sea_level eastward_wind  \
# station_id
# KGYH                                         1003.81    -10.392305
# KMFV        AO2 T00890049                    1015.92     -5.908847
# KPLD            AO2 P0007                     989.18     -7.660444
# KIKT                  A01                    1005.29     19.052559
# PAKU                                         1014.89    -20.680963
# ...                   ...                        ...           ...
# OIYY                                         1012.21     -3.464102
# ORNI                                         1017.39      6.062178
# NFTV                                         1011.92    -15.000000
# NFTL                                         1013.28    -22.000000
# NFTF                                         1014.11    -16.000000
#
#             northward_wind
# station_id
# KGYH         -6.000000e+00
# KMFV          1.041889e+00
# KPLD          6.427876e+00
# KIKT          1.100000e+01
# PAKU          3.646612e+00
# ...                    ...
# OIYY          2.000000e+00
# ORNI          3.500000e+00
# NFTV         -9.184851e-16
# NFTL         -1.347111e-15
# NFTF         -9.797174e-16
#
# [9383 rows x 31 columns]

# %% [markdown]
# ### REMOVE DATA THAT IS INCOMPLETE ###
# Just remove data with no wind direction or wind speed.

# %%
data = data.dropna(how='any', subset=['wind_direction','wind_speed'])

print(data)
# Out:
#            station_id  latitude   longitude  elevation           date_time  \
# station_id
# KGYH             KGYH     34.75  -82.380000      292.0 2024-01-12 20:47:00
# KMFV             KMFV     37.63  -75.770000       15.0 2024-01-12 20:55:00
# KPLD             KPLD     40.45  -84.983333      282.0 2024-01-12 20:55:00
# KIKT             KIKT     28.52  -88.280000       25.0 2024-01-12 20:50:00
# PAKU             PAKU     70.31 -149.580000        2.0 2024-01-12 20:45:00
# ...               ...       ...         ...        ...                 ...
# OIYY             OIYY     31.90   54.280000     1236.0 2024-01-12 21:50:00
# ORNI             ORNI     31.98   44.400000       53.0 2024-01-14 21:00:00
# NFTV             NFTV    -18.57 -173.970000       71.0 2024-01-12 21:00:00
# NFTL             NFTL    -19.78 -174.330000        3.0 2024-01-12 21:00:00
# NFTF             NFTF    -21.23 -175.150000       38.0 2024-01-12 21:00:00
#
#             wind_direction  wind_speed  wind_gust  visibility current_wx1  \
# station_id
# KGYH                  60.0        12.0        NaN    4828.032         +RA
# KMFV                 100.0         6.0        NaN   16093.440         NaN
# KPLD                 130.0        10.0        NaN    8046.720         -SN
# KIKT                 240.0        22.0       32.0    4828.032          BR
# PAKU                 100.0        21.0        NaN    4828.032        BLSN
# ...                    ...         ...        ...         ...         ...
# OIYY                 120.0         4.0        NaN   10000.000         NaN
# ORNI                 240.0         7.0        NaN    6000.000         NaN
# NFTV                  90.0        15.0        NaN    9999.000       -SHRA
# NFTL                  90.0        22.0        NaN    9999.000         NaN
# NFTF                  90.0        16.0        NaN    9999.000         NaN
#
#             ... air_temperature dew_point_temperature altimeter  \
# station_id  ...
# KGYH        ...            44.6                  42.8     29.61
# KMFV        ...            48.2                  41.0     29.99
# KPLD        ...            33.8                  33.8     29.16
# KIKT        ...            73.4                  69.8     29.68
# PAKU        ...             5.0                   3.2     29.96
# ...         ...             ...                   ...       ...
# OIYY        ...            51.8                  26.6     29.88
# ORNI        ...            51.8                  42.8     30.03
# NFTV        ...            82.4                  75.2     29.88
# NFTL        ...            84.2                  73.4     29.91
# NFTF        ...            80.6                  73.4     29.94
#
#             current_wx1_symbol current_wx2_symbol  current_wx3_symbol  \
# station_id
# KGYH                        65                 10                   0
# KMFV                         0                  0                   0
# KPLD                        71                  0                   0
# KIKT                        10                  0                   0
# PAKU                        38                 10                   0
# ...                        ...                ...                 ...
# OIYY                         0                  0                   0
# ORNI                         0                  0                   0
# NFTV                        80                  0                   0
# NFTL                         0                  0                   0
# NFTF                         0                  0                   0
#
#                   remarks  air_pressure_at_sea_level eastward_wind  \
# station_id
# KGYH                                         1003.81    -10.392305
# KMFV        AO2 T00890049                    1015.92     -5.908847
# KPLD            AO2 P0007                     989.18     -7.660444
# KIKT                  A01                    1005.29     19.052559
# PAKU                                         1014.89    -20.680963
# ...                   ...                        ...           ...
# OIYY                                         1012.21     -3.464102
# ORNI                                         1017.39      6.062178
# NFTV                                         1011.92    -15.000000
# NFTL                                         1013.28    -22.000000
# NFTF                                         1014.11    -16.000000
#
#             northward_wind
# station_id
# KGYH         -6.000000e+00
# KMFV          1.041889e+00
# KPLD          6.427876e+00
# KIKT          1.100000e+01
# PAKU          3.646612e+00
# ...                    ...
# OIYY          2.000000e+00
# ORNI          3.500000e+00
# NFTV         -9.184851e-16
# NFTL         -1.347111e-15
# NFTF         -9.797174e-16
#
# [8878 rows x 31 columns]

# %% [markdown]
# ### PLOT MAP ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND)
ax.add_feature(cfeature.OCEAN)
ax.add_feature(cfeature.LAKES)
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

fig.tight_layout()

#save the map as empty_map.png
plt.savefig('empty map.png')

# %% [markdown]
# ### PLOT A NEW MAP BUT ADD SURFACE OBS LOCATIONS ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND,zorder=1)
ax.add_feature(cfeature.OCEAN,zorder=0)
ax.add_feature(cfeature.LAKES,zorder=2)
ax.add_feature(cfeature.COASTLINE,zorder=1)
ax.add_feature(cfeature.STATES,zorder=3)
ax.add_feature(cfeature.BORDERS,zorder=3)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

#plot surface obs using scatter plot
plt.scatter(data.longitude, data.latitude,s=3,transform=ccrs.PlateCarree(),zorder=9)


fig.tight_layout()
#save the map as obs_locations.png
plt.savefig('obs_locations.png',bbox_inches='tight')

#bbox_inches='tight' is to make saved images more clear

# %% [markdown]
# ### WAY TOO MANY OBS ###
# There are way too many obs for us to be able to actually see what the weather is.  We need to "thin" the obs in areas of very high densiy.
#
# We'll do this using the *metpy.calc.reduce_point_density* function.
#
# Find a density that works well for you.  The units for density are meters, so 100000 is roughly one observation/100km.

# %%
#first convert the lat/lon to map projection coordinates
locs = proj.transform_points(ccrs.PlateCarree(),data['longitude'].values,data['latitude'].values)
#print(data.longitude, data.latitude)
#print(locs)



#now thin the data
data_thinned = data[mpcalc.reduce_point_density(locs, 300*units('km'))]


#data_thinned = data[mpcalc.reduce_point_density(locs, 100*units('km'))]
#print(data_thinned)

# %% [markdown]
# ### SAVE OBS LOCATIONS ON NEW MAP ###

# %%
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.LAND,zorder=1)
ax.add_feature(cfeature.OCEAN,zorder=0)
ax.add_feature(cfeature.LAKES,zorder=2)
ax.add_feature(cfeature.COASTLINE,zorder=1)
ax.add_feature(cfeature.STATES,zorder=3)
ax.add_feature(cfeature.BORDERS,zorder=3)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

#plot surface obs using scatter plot
plt.scatter(data_thinned.longitude, data_thinned.latitude,s=3,transform=ccrs.PlateCarree(),zorder=9)


fig.tight_layout()
#save the map as obs_locations.png
plt.savefig('obs_locations.png',bbox_inches='tight')

#bbox_inches='tight' is to make saved images more clear



#save the map as obs_locations_thinned.png
plt.savefig('obs_locations_thinned.png')

# %% [markdown]
# ### ONCE YOU'RE HAPPY WITH THE DENSITY, PLOT SURFACE STATIONS ###
# For this use the *StationPlot* object in metpy -> https://unidata.github.io/MetPy/latest/api/generated/metpy.plots.StationPlot.html

# %%
#save the map as simple_surface_obs.png
#map projection jusing a Lambert Conformal Projection
#we'll center the map at 100W,35N
proj = ccrs.LambertConformal(central_longitude=-100,central_latitude=35)

#create 10" x 10" figure with a dpi=100
fig = plt.figure(figsize=(10,10),dpi=100)

#add subplot with projection
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
#ax.add_feature(cfeature.LAND,zorder=1) #just gets rid of color
#ax.add_feature(cfeature.OCEAN,zorder=0)
#ax.add_feature(cfeature.LAKES,zorder=2)
ax.add_feature(cfeature.COASTLINE,zorder=1)
ax.add_feature(cfeature.STATES,zorder=3)
ax.add_feature(cfeature.BORDERS,zorder=3)

#zoom on the CONUS
#lon_min = -120
#lon_max = -75
#lat_min = 23
#lat_max = 50
ax.set_extent((-120, -75, 23, 50))

stationplots = StationPlot(ax,data_thinned['longitude'],data_thinned['latitude'],transform=ccrs.PlateCarree(), clip_on=True)

simple_layout.plot(stationplots, data_thinned)


fig.tight_layout()
#save the map as obs_locations.png
plt.savefig('obs_locations.png',bbox_inches='tight')

#bbox_inches='tight' is to make saved images more clear



#save the map as obs_locations_thinned.png
plt.savefig('obs_locations_thinned.png')

# %% [markdown]
# ### PLOT NORTHERN PLAINS ###
# Now we are going to focus on the Northern Great Plains and make a custom layout.<br>
# We will set the extent to 150W to 90W and 40N to 50N.<br>
# We will also need to re-thin the data since we will be zoomed in and can see more obs.<br><br>
# Data that will be plotted:<br>
#  - Temperature in the top left
#  - Dewpoint in bottom left
#  - Pressure in top right
#  - Station ID in bottom right
#  - Current weather on left
#  - Visibility in miles on far left
#  - Wind barb in black
#  - Wind gust barb in red

# %%
#rethin data (90km works well)
data_thinned = data[mpcalc.reduce_point_density(locs, 90*units('km'))]

# %%
#create wind gust vectors
#do this by multiplying each component by the ratio of gust to speed
#get wind direction from metpy
#print (u)
#get wind gust components assuming same direction using metpy wind components

u = data_thinned.eastward_wind.values * units('knots')
v = data_thinned.northward_wind.values * units('knots')
gust = data_thinned.wind_gust.values * units('knots')

wind_direction = mpcalc.wind_direction(u,v)
#metpy.calc.wind_direction(data_thinned.eastward_wind, data_thinned.northward_wind, convention='from')

ug, vg = mpcalc.wind_components(gust, wind_direction)
#metpy.calc.wind_components(speed, wind_direction)

for i in ug:
    print(i)
# Out:
# nan knot
# nan knot
# nan knot
# 27.712812921102028 knot
# nan knot
# 24.6201938253052 knot
# 20.0 knot
# 25.371700761219525 knot
# 34.0 knot
# nan knot
# 23.0 knot
# 10.500000000000002 knot
# 18.711347307231954 knot
# -6.42498257367642 knot
# 3.2993153756716773 knot
# -13.155696691002717 knot
# nan knot
# -10.284601754984632 knot
# nan knot
# -26.311393382005434 knot
# -9.918584156444398 knot
# -10.284601754984632 knot
# nan knot
# nan knot
# nan knot
# 4.341204441673262 knot
# 20.673237657289985 knot
# 22.0 knot
# 18.0 knot
# nan knot
# nan knot
# 9.641814145298088 knot
# 27.574617084341824 knot
# 21.0 knot
# nan knot
# -16.741731801207536 knot
# nan knot
# nan knot
# nan knot
# -14.554844419260583 knot
# nan knot
# nan knot
# -16.06969024216348 knot
# nan knot
# -12.499999999999998 knot
# -17.499999999999996 knot
# -12.21296458404425 knot
# -19.15111107797445 knot
# -5.814342436536371 knot
# nan knot
# -13.788799976141604 knot
# -13.788799976141604 knot
# -15.974774553360444 knot
# 38.40750236747612 knot
# nan knot
# nan knot
# -23.78314155840196 knot
# nan knot
# -17.619022191736494 knot
# nan knot
# 5.13030214988503 knot
# nan knot
# nan knot
# nan knot
# -29.13047124436316 knot
# 37.587704831436334 knot
# nan knot
# 23.492315519647708 knot
# nan knot
# 17.726539554219748 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 12.990381056766577 knot
# nan knot
# nan knot
# 30.0 knot
# 7.524443153164711 knot
# 17.32050807568877 knot
# 22.981333293569335 knot
# nan knot
# 22.516660498395403 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 22.516660498395403 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 33.48346360241507 knot
# -2.9391523179536475e-15 knot
# nan knot
# 3.472963553338608 knot
# nan knot
# nan knot
# -25.98076211353316 knot
# nan knot
# nan knot
# -44.31634888554936 knot
# nan knot
# nan knot
# nan knot
# 35.453079108439496 knot
# 21.61293027807589 knot
# 22.5526228988618 knot
# 30.07016386514907 knot
# nan knot
# -13.022755533022627 knot
# 33.48346360241508 knot
# 14.722431864335457 knot
# nan knot
# nan knot
# 33.0 knot
# 26.58980933132962 knot
# 22.650578319280786 knot
# -11.570176974357711 knot
# nan knot
# nan knot
# nan knot
# -4.408728476930472e-15 knot
# nan knot
# 22.5526228988618 knot
# nan knot
# -11.570176974357711 knot
# nan knot
# nan knot
# 25.11473670974872 knot
# 16.852977748617512 knot
# 30.52904034337845 knot
# 13.498539803417332 knot
# 19.733545036504076 knot
# nan knot
# 13.500000000000034 knot
# 12.50000000000003 knot
# nan knot
# nan knot
# -17.726539554219745 knot
# nan knot
# 7.524443153164709 knot
# nan knot
# 18.79385241571817 knot
# 18.186533479473212 knot
# -17.999999999999996 knot
# nan knot
# -20.673237657289985 knot
# 8.550503583141717 knot
# 12.50000000000003 knot
# -21.665770566268577 knot
# 13.500000000000034 knot
# nan knot
# nan knot
# nan knot
# 11.570176974357713 knot
# -19.052558883257653 knot
# -23.382685902179844 knot
# nan knot
# 18.385066634855477 knot
# -9.499999999999996 knot
# -14.55484441926058 knot
# 29.544232590366242 knot
# 34.641016151377535 knot
# 4.34120444167326 knot
# 18.38506663485547 knot
# nan knot
# nan knot
# 14.554844419260585 knot
# nan knot
# nan knot
# 20.784609690826528 knot
# nan knot
# 24.0 knot
# nan knot
# -16.852977748617516 knot
# nan knot
# nan knot
# nan knot
# 21.44924440733139 knot
# 12.855752193730785 knot
# 26.311393382005434 knot
# nan knot
# 32.498655849402866 knot
# nan knot
# -22.650578319280786 knot
# nan knot
# 3.993908086339399 knot
# nan knot
# nan knot
# nan knot
# 10.000000000000025 knot
# nan knot
# 31.949549106720884 knot
# nan knot
# 25.980762113533157 knot
# -25.71150438746157 knot
# 27.57759995228321 knot
# 23.74737773668832 knot
# nan knot
# -21.665770566268577 knot
# 15.000000000000004 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 7.524443153164709 knot
# 18.500000000000046 knot
# 21.665770566268577 knot
# nan knot
# 23.635386072292995 knot
# 3.4729635533386096 knot
# nan knot
# nan knot
# nan knot
# -23.747377736688318 knot
# nan knot
# -9.499999999999998 knot
# nan knot
# 7.524443153164709 knot
# 7.524443153164709 knot
# nan knot
# nan knot
# 5.035797152340984 knot
# 30.310889132455344 knot
# 8.572527594031473e-15 knot
# nan knot
# nan knot
# nan knot
# 28.559424837354033 knot
# -3.125667198004745 knot
# 11.500000000000028 knot
# 25.371700761219525 knot
# nan knot
# nan knot
# 18.385066634855477 knot
# 32.93991105411606 knot
# 25.980762113533157 knot
# nan knot
# 16.50000000000004 knot
# 14.000000000000034 knot
# nan knot
# nan knot
# 12.312725159724069 knot
# 37.58770483143634 knot
# 24.432008140433616 knot
# nan knot
# nan knot
# 4.341204441673262 knot
# -25.60500157831741 knot
# nan knot
# 16.06969024216349 knot
# 26.58980933132962 knot
# 16.08693330549854 knot
# 30.0 knot
# nan knot
# 16.91446717414635 knot
# -13.022755533022627 knot
# nan knot
# nan knot
# nan knot
# -27.574617084341824 knot
# -15.974774553360444 knot
# nan knot
# -6.498382723187701 knot
# 4.167556264006329 knot
# -28.19077862357725 knot
# -6.999999999999999 knot
# -28.559424837354033 knot
# -25.279466622926275 knot
# nan knot
# 11.570176974357713 knot
# 11.000000000000027 knot
# 4.68850079700712 knot
# 38.40750236747611 knot
# 18.500000000000046 knot
# nan knot
# 26.58980933132962 knot
# nan knot
# nan knot
# -5.556741685341771 knot
# 13.500000000000034 knot
# 22.981333293569342 knot
# 29.544232590366242 knot
# 20.68319996421241 knot
# 21.854778729342346 knot
# 28.19077862357725 knot
# nan knot
# 20.680962813256368 knot
# 32.498655849402866 knot
# nan knot
# nan knot
# nan knot
# 12.256711089903646 knot
# 18.385066634855477 knot
# 10.284601754984633 knot
# 21.650635094610966 knot
# -22.650578319280786 knot
# 9.234543869793052 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -17.61902219173649 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 20.784609690826528 knot
# 33.0 knot
# nan knot
# nan knot
# 29.544232590366242 knot
# nan knot
# nan knot
# 28.559424837354033 knot
# 3.6466117310055397 knot
# nan knot
# -3.061616997868383e-15 knot
# 23.635386072292995 knot
# 22.650578319280786 knot
# 37.42269461446391 knot
# nan knot
# 45.03332099679079 knot
# nan knot
# 16.06969024216349 knot
# -16.0 knot
# nan knot
# nan knot
# 25.605001578317413 knot
# 23.635386072292995 knot
# 23.49231551964771 knot
# 10.26060429977006 knot
# 29.544232590366242 knot
# 23.0 knot
# nan knot
# nan knot
# -25.60500157831741 knot
# nan knot
# nan knot
# nan knot
# 25.980762113533157 knot
# 25.371700761219525 knot
# nan knot
# nan knot
# nan knot
# -14.55484441926058 knot
# nan knot
# nan knot
# -20.673237657289985 knot
# 15.756924048195328 knot
# 19.05255888325765 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 28.19077862357725 knot
# nan knot
# -15.499999999999998 knot
# -10.927389364671171 knot
# nan knot
# nan knot
# 16.50000000000004 knot
# nan knot
# -9.999999999999996 knot
# -23.63538607229299 knot
# nan knot
# -24.4259291680885 knot
# -24.513422179807296 knot
# 3.299315375671679 knot
# -18.711347307231954 knot
# -18.385066634855473 knot
# nan knot
# -18.640840680909644 knot
# nan knot
# nan knot
# -23.747377736688318 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -23.499999999999996 knot
# -22.497566339028882 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 27.25108600279134 knot
# 22.0 knot
# nan knot
# nan knot
# 7.866463296490378 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 31.949549106720887 knot
# nan knot
# 16.06969024216349 knot
# nan knot
# nan knot
# -37.587704831436334 knot
# nan knot
# nan knot
# nan knot
# 16.08693330549854 knot
# nan knot
# 26.311393382005434 knot
# 15.42690263247695 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 11.500000000000028 knot
# -31.4078221678781 knot
# nan knot
# 30.52904034337845 knot
# -16.45448267190433 knot
# nan knot
# -33.48346360241507 knot
# nan knot
# -32.498655849402866 knot
# -28.343644395402187 knot
# -14.095389311788624 knot
# nan knot
# nan knot
# 15.756924048195328 knot
# 31.00985648593498 knot
# 22.5526228988618 knot
# 3.91886975727153e-15 knot
# 15.500000000000037 knot
# 2.604722665003957 knot
# nan knot
# nan knot
# 14.772116295183121 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -10.260604299770055 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -12.85575219373079 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 12.855752193730792 knot
# 33.0 knot
# 12.990381056766577 knot
# 7.866463296490378 knot
# nan knot
# nan knot
# 27.251086002791343 knot
# 11.490666646784668 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -35.708319589864516 knot
# 7.524443153164709 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -7.182423009839043 knot
# 21.211991119655806 knot
# nan knot
# -3.820259908672467 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 19.926415900282727 knot
# 20.0 knot
# 14.141327413103872 knot
# 25.60500157831741 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 16.0 knot
# 30.07016386514907 knot
# 12.996765446375408 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 5.633375276077825e-15 knot
# nan knot
# -19.0 knot
# 3.472963553338608 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -39.39231012048832 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 8.000000000000002 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 29.544232590366242 knot
# nan knot
# nan knot
# nan knot
# 19.91715552109343 knot
# 11.570176974357713 knot
# 16.852977748617512 knot
# 20.0 knot
# 19.05255888325765 knot
# 15.588457268119894 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 25.371700761219525 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 14.141327413103872 knot
# 31.513848096390657 knot
# 19.283628290596187 knot
# 8.999026535611554 knot
# 9.234543869793054 knot
# -22.0 knot
# nan knot
# 12.212964584044252 knot
# nan knot
# 14.554844419260585 knot
# nan knot
# 14.500000000000036 knot
# 14.722431864335457 knot
# 26.58980933132962 knot
# nan knot
# 12.000000000000028 knot
# 17.726539554219748 knot
# 16.00000000000004 knot
# 23.635386072292995 knot
# nan knot
# nan knot
# 25.980762113533157 knot
# -5.130302149885033 knot
# 12.855752193730792 knot
# 31.51384809639066 knot
# nan knot
# nan knot
# nan knot
# 29.444863728670914 knot
# 14.000000000000034 knot
# 3.8202599086724685 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -20.673237657289985 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -19.69615506024416 knot
# nan knot
# nan knot
# 25.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -25.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -31.513848096390657 knot
# -10.260604299770065 knot
# nan knot
# -31.176914536239792 knot
# nan knot
# nan knot
# -27.251086002791343 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -24.248711305964285 knot
# 13.500000000000034 knot
# nan knot
# -18.469087739586097 knot
# nan knot
# nan knot
# -22.497566339028882 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -21.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 3.6466117310055397 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 3.646611731005538 knot
# 3.993908086339399 knot
# -10.602624443095722 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 27.57759995228321 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -3.061616997868383e-15 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -15.320888862379558 knot
# -10.72462220366569 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -17.61902219173649 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -18.793852415718167 knot
# nan knot
# nan knot
# nan knot
# 9.641814145298094 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -4.688500797007119 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -13.499999999999995 knot
# nan knot
# 4.653657836759942e-15 knot
# nan knot
# -5.130302149885033 knot
# nan knot
# 23.49231551964771 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -25.60500157831741 knot
# nan knot
# nan knot
# nan knot
# 5.130302149885029 knot
# -12.21296458404425 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 11.570176974357713 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -14.499999999999998 knot
# nan knot
# nan knot
# 7.293223462011076 knot
# nan knot
# nan knot
# -30.529040343378448 knot
# nan knot
# nan knot
# 19.05255888325765 knot
# -22.981333293569335 knot
# nan knot
# nan knot
# nan knot
# -22.650578319280786 knot
# 12.990381056766578 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -12.212964584044245 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 16.741731801207536 knot
# nan knot
# 13.788799976141602 knot
# nan knot
# 16.0 knot
# nan knot
# 19.918584287042087 knot
# 13.856406460551018 knot
# nan knot
# 15.0 knot
# nan knot
# 23.635386072292995 knot
# nan knot
# 25.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -34.468271355427284 knot
# -22.21528885045036 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 30.070163865149066 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 17.854159794932258 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 16.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# 18.793852415718167 knot
# nan knot
# -18.38506663485547 knot
# nan knot
# -14.722431864335455 knot
# 7.500000000000002 knot
# 15.0 knot
# -28.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 14.554844419260585 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -15.756924048195328 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -14.55484441926058 knot
# nan knot
# nan knot
# 28.0 knot
# 9.500000000000023 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 25.605001578317413 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -34.468271355427284 knot
# -15.0 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 21.665770566268577 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 32.90896534380866 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 41.34647531457997 knot
# 37.23909236273085 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -30.529040343378448 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -22.650578319280786 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -19.733545036504076 knot
# nan knot
# nan knot
# nan knot
# nan knot
# -16.086933305498537 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -6.84040286651337 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 15.426902632476942 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# 28.578838324886473 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -4.5148526193401874 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -24.24871130596428 knot
# nan knot
# nan knot
# nan knot
# -10.602624443095735 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# -33.48346360241507 knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot
# nan knot

# %%
#map projection
proj = ccrs.LambertConformal(central_longitude=-95,central_latitude=35)

#create figure
fig = plt.figure(figsize=(10,10),dpi=100)
ax = fig.add_subplot(1,1,1,projection=proj)

#add elements to make map more useable
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
ax.add_feature(cfeature.BORDERS)

#zoom on the Northern Plains
ax.set_extent((-105, -90, 40, 50))


#create stationplot (will actually need to create 2 to handle wind gusts)
stationplots = StationPlot(ax,data_thinned['longitude'],data_thinned['latitude'],transform=ccrs.PlateCarree(), clip_on=True, fontsize=10)
stationplots_gusts = StationPlot(ax,data_thinned['longitude'],data_thinned['latitude'],transform=ccrs.PlateCarree(), clip_on=True, fontsize=10)

#temperature in red
stationplots.plot_parameter((-1,1), data_thinned['air_temperature'].values, color='red')

#dewpoint in dark green

stationplots.plot_parameter((-1,-1), data_thinned['dew_point_temperature'].values,color='darkgreen')
#give coordinates (-1,1) in place of 'SW'

#pressure (need to format to be the final 3 digits)
stationplots.plot_parameter((1, 1), data_thinned['air_pressure_at_sea_level'].values, 
                            color='black', formatter=lambda v: format(10 * v, '.0f')[-3:])
#p = 1023.2; want 232, so do p * 10 = 10232


#station ID in dark blue
stationplots.plot_text((1.5,-1), data_thinned['station_id'].values,color='darkblue')


#visibility in black (need to convert from meters to miles)
stationplots.plot_parameter((-2, 0), data_thinned['visibility'].values*units('meters').to(units('miles')), color='black')

#wind gust in red
stationplots_gusts.plot_barb(ug,vg, color='red', zorder=9)
                            

#wind in black
stationplots.plot_barb(u,v, color='black', zorder=10)

#cloud cover
stationplots.plot_symbol('C', data_thinned['cloud_coverage'].values, sky_cover)

#current weather
stationplots.plot_symbol('W', data_thinned['current_wx1_symbol'].values, current_weather)

#save the map as surface_obs.png

plt.savefig('surface_obs.png')
